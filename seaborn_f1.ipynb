# %% [markdown]
# <a href="https://colab.research.google.com/github/srinath698/seaborn-for-machine-learning/blob/main/seaborn_f1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# !ls "/content/drive/MyDrive/Colab Notebooks"
# Out:
# ls: cannot access '/content/drive/MyDrive/Colab Notebooks': No such file or directory

# %%
# !ls /content/drive
# Out:
# ls: cannot access '/content/drive': No such file or directory

# %%
import os
print(os.getcwd())
# Out:
# /content

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls /content
# Out:
# drive  sample_data

# %%
# !find /content/drive -iname "*superstore*"
# Out:
# /content/drive/MyDrive/Colab Notebooks/datasets/Sample - Superstore.csv

# %% [markdown]
# # New Section

# %%
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/datasets/Sample - Superstore.csv")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# /tmp/ipykernel_4265/2486749255.py in <cell line: 0>()
# ----> 1 df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/datasets/Sample - Superstore.csv")
#
# ...

# %%
# !file "/content/drive/MyDrive/Colab Notebooks/datasets/Sample - Superstore.csv"
# Out:
# /content/drive/MyDrive/Colab Notebooks/datasets/Sample - Superstore.csv: CSV text

# %%
import pandas as pd

df = pd.read_csv(
    "/content/drive/MyDrive/Colab Notebooks/datasets/Sample - Superstore.csv",
    encoding="latin1"
)

df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
import seaborn as sns
sns.scatterplot(
    data=df,
    x="Sales",
    y='Profit',
    hue='Category',
    style='Segment',
    size='Quantity'
)
# Out:
# <Axes: xlabel='Sales', ylabel='Profit'>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import os
print(os.getcwd())
# Out:
# /content

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls /content
# Out:
# drive  sample_data

# %%
# !file "/content/drive/MyDrive/Colab Notebooks/datasets/Sample - Superstore.csv"
# Out:
# /content/drive/MyDrive/Colab Notebooks/datasets/Sample - Superstore.csv: CSV text

# %%
import pandas as pd

df = pd.read_csv(
    "/content/drive/MyDrive/Colab Notebooks/datasets/Sample - Superstore.csv",
    encoding="latin1"
)

df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
import seaborn as sns
import pandas as pd
sns.lineplot(
    data=df,
    x='Sales',
    y='Category',
    hue='Segment',



)
# Out:
# <Axes: xlabel='Sales', ylabel='Category'>

# %%
sns.histplot(
    data=df,
    x='Sales',
    hue='Segment',

    bins=30,
    kde='True'
)
# Out:
# <Axes: xlabel='Sales', ylabel='Count'>
